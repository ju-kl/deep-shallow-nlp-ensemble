# %%
import numpy as np
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
from concurrent.futures import ThreadPoolExecutor
import pickle

# %%
df = pd.read_csv('patients.csv')
df.dropna(inplace = True)

# %% [markdown]
# **BERT question answering**

# %%
# initialize model and tokenizer
bert_model = AutoModelForQuestionAnswering.from_pretrained("bert-large-uncased-whole-word-masking-finetuned-squad")
bert_tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased-whole-word-masking-finetuned-squad")

# %%
def bert_qa(question, text):
    '''
    Takes two strings: the first is the question string, the second is the text it searches for the answer. 
    Returns what it thinks the answer is.
    '''
    inputs = bert_tokenizer.encode_plus(question, text, add_special_tokens = True, return_tensors = 'pt')
    input_ids = inputs["input_ids"].tolist()[0]
    
    text_tokens = bert_tokenizer.convert_ids_to_tokens(input_ids)
    sep_index = text_tokens.index('[SEP]') + 1
    answer_start_scores, answer_end_scores = bert_model(**inputs)
    
    if torch.max(answer_start_scores) and torch.max(answer_end_scores) < 5:
        return(np.nan)
    
    answer_start = torch.argmax(answer_start_scores[0][sep_index:])
    answer_end = torch.argmax(answer_end_scores[0][sep_index:]) + 1
    answer_start += sep_index 
    answer_end += sep_index
    
    answer = bert_tokenizer.convert_tokens_to_string(bert_tokenizer.convert_ids_to_tokens(input_ids[answer_start:answer_end]))
    
    return(answer)

# %% [markdown]
# **BioBERT question answering**

# %%
# initialize model and tokenizer
biobert_model = AutoModelForQuestionAnswering.from_pretrained("gdario/biobert_bioasq")
biobert_tokenizer = AutoTokenizer.from_pretrained("gdario/biobert_bioasq")

# %%
def biobert_qa(question, text):
    '''
    Takes two strings: the first is the question string, the second is the text it searches for the answer. 
    Returns what it thinks the answer is.
    '''
    inputs = biobert_tokenizer.encode_plus(question, text, add_special_tokens = True, return_tensors = 'pt')
    input_ids = inputs["input_ids"].tolist()[0]
    
    text_tokens = biobert_tokenizer.convert_ids_to_tokens(input_ids)
    sep_index = text_tokens.index('[SEP]') + 1
    answer_start_scores, answer_end_scores = biobert_model(**inputs)
    
    if torch.max(answer_start_scores) and torch.max(answer_end_scores) < 1:
        return(np.nan)
    
    answer_start = torch.argmax(answer_start_scores[0][sep_index:])
    answer_end = torch.argmax(answer_end_scores[0][sep_index:]) + 1
    answer_start += sep_index 
    answer_end += sep_index
    
    answer = biobert_tokenizer.convert_tokens_to_string(biobert_tokenizer.convert_ids_to_tokens(input_ids[answer_start:answer_end]))
    
    return(answer)

# %%
bert_qa('Does the patient have any allergies?', 'The patient agreed to the surgery. And likely will update his presentation. No known allergies.')
# Out:
# ('no known allergies', 5.076744556427002, 2.9227135181427)

# %% [markdown]
# **Looping through the data**

# %%
questions = {'covid': ['Does the patient have covid-19?', 'Does the patient have coronavirus?', 'Does the patient have corona?'],
            'age': ['How old is the patient?', 'What is the patient’s age?', 'How many yo is the patient?'],
            'sex': ['Is the patient male or female?', 'Is the patient a woman?', 'Is the patient a boy?', 'Is the patient m or f?'],
            'consent': ['Has the patient consented?', 'Has the patient agreed?'],
            'bmi': ['What is the patient’s bmi?', 'What is the patient’s body mass index?', 'Is the patient obese?'],
            'height': ['How tall is the patient?', 'What is the patient’s height?', 'How many ft is the patient?'],
            'weight': ['How much does the patient weigh?', 'How many lbs is the patient?', 'How many kg is the patient?', 'What is the patient’s weight?'],
            'allergy': ['Does the patient have any allergies?', 'Is the patient allergic?', 'Has the patient had any allergic reactions?'],
            'hiv': ['Does the patient have hiv?', 'Does the patient have human immunodeficiency virus?'],
            'hepatitis': ['Does the patient have hepatitis?', 'Does the patient have any problems with their liver?', 'Does the patient suffer from any hepatic diesease?'],
            'alt_ast': ['Does the patient have ALT/AST > 4 times ULN?', 'How does patient’s ALT/AST compare to upper normal limit?', 'How does patient’s ALT/AST compare to ULN?'],
            'opiods': ['Does the patient use opioids?', 'Is the patient using any sedatives?', 'Is the patient using any painkillers?']}

# %%
questions = {'consent': ['Has the patient consented?'],
            'allergy': ['Does the patient have any allergies?'],
            'hiv': ['Does the patient have HIV?'],
            'hepatitis': ['Does the patient have liver problems?'],
            'opiods': ['Does the patient use opioids?']}

# %%
bert_utility_tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased-whole-word-masking-finetuned-squad")
biobert_utility_tokenizer = AutoTokenizer.from_pretrained("gdario/biobert_bioasq")

# %%
results = pd.DataFrame(columns = ['patient_id', 'consent', 'allergy', 'hiv', 'hepatitis', 'opiods'])

# %% [markdown]
# **BERT**

# %%
for patient, note, i in zip(df['patient_id'], df['notes'], range(len(df))):
    print('Questioning patient', patient)
    # ============ For notes greater than 450 tokens long ================
    # if the note length is greater than the 450 tokens we'll split it and work on each split separately
    note_tokenized = bert_utility_tokenizer.tokenize(note)
    note_length = len(note_tokenized)
    if note_length > 450:
        # split the data into =<450-sized chunks
        split_n = (note_length // 450) + 1
        split_start = 0
        split_end = 450
        split_text = bert_utility_tokenizer.convert_tokens_to_string(note_tokenized[split_start:split_end])
        
        # initialize scorer
        scorer = {'patient_id':[patient], 'consent':[[]], 'allergy':[[]], 'hiv':[[]], 'hepatitis':[[]],
                 'opiods':[[]]}
        for criteria, index in zip(questions, range(len(questions))):
            if index == 0:
                continue
            for question in questions.get(criteria):
                mention = bert_qa(question, split_text)
                if not pd.isna(mention):
                    scorer[criteria][0].append(mention)   
        
#         for n in range(split_n):
#             # if we're in the last split
#             if n == (split_n - 1):
#                 split_text = bert_utility_tokenizer.convert_tokens_to_string(note_tokenized[note_length - (note_length % 450): ])
#                 for criteria, index in zip(questions, range(len(questions))):
#                     if index == 0:
#                         continue
#                     for question in questions.get(criteria):
#                         mention = bert_qa(question, split_text)
#                         if not pd.isna(mention):
#                             scorer[criteria][0].append(mention)
#             # otherwise, for each successive split
#             elif n != 0:
#                 split_start += 450
#                 split_end += 450
#                 split_text = bert_utility_tokenizer.convert_tokens_to_string(note_tokenized[split_start:split_end])
#                 for criteria, index in zip(questions, range(len(questions))):
#                     if index == 0:
#                         continue
#                     for question in questions.get(criteria):
#                         mention = bert_qa(question, split_text)
#                         if not pd.isna(mention):
#                             scorer[criteria][0].append(mention)
#             # for the first split
#             elif n == 0:
#                 for criteria, index in zip(questions, range(len(questions))):
#                     if index == 0:
#                         continue
#                     for question in questions.get(criteria):
#                         mention = bert_qa(question, split_text)
#                         if not pd.isna(mention):
#                             scorer[criteria][0].append(mention)
        # record results
        scorer_df = pd.DataFrame(scorer)
        results = results.append(scorer_df, ignore_index = True)
        print('Added results for patient', patient)
        if i % 25 == 0:
            print('checkpoint!')
            results.to_csv('checkpoint_results.csv')
    # =========== For notes less than 450 tokens long ===================
    elif note_length <= 450:
        # set up the scorer dict
        scorer = {'patient_id':[patient], 'consent':[[]], 'allergy':[[]], 'hiv':[[]], 'hepatitis':[[]],
                 'opiods':[[]]}
        for criteria, index in zip(questions, range(len(questions))):
            if index == 0:
                continue
            for question in questions.get(criteria):
                mention = bert_qa(question, note)
                if not pd.isna(mention):
                    scorer[criteria][0].append(mention)

        # record results in the dictionary
        scorer_df = pd.DataFrame(scorer)
        results = results.append(scorer_df, ignore_index = True)
        print('Added results for patient', patient)
        if i % 25 == 0:
            print('checkpoint!')
            results.to_csv('checkpoint_results.csv')
# Out:
# Questioning patient 1081.0
# Added results for patient 1081.0
# checkpoint!
# Questioning patient 1080.0
# Added results for patient 1080.0
# Questioning patient 1079.0
# Added results for patient 1079.0
# Questioning patient 1078.0
# Added results for patient 1078.0
# Questioning patient 1077.0
# Added results for patient 1077.0
# Questioning patient 1076.0
# Added results for patient 1076.0
# Questioning patient 1075.0
# Added results for patient 1075.0
# Questioning patient 1074.0
# Added results for patient 1074.0
# Questioning patient 1073.0
# Added results for patient 1073.0
# Questioning patient 1072.0
# Added results for patient 1072.0
# Questioning patient 1071.0
# Added results for patient 1071.0
# Questioning patient 1070.0
# Added results for patient 1070.0
# Questioning patient 1069.0
# Added results for patient 1069.0
# Questioning patient 1068.0
# Added results for patient 1068.0
# Questioning patient 1067.0
# Added results for patient 1067.0
# Questioning patient 1066.0
# Added results for patient 1066.0
# Questioning patient 1065.0
# Added results for patient 1065.0
# Questioning patient 1064.0
# Added results for patient 1064.0
# Questioning patient 1063.0
# Added results for patient 1063.0
# Questioning patient 1062.0
# Added results for patient 1062.0
# Questioning patient 1061.0
# Added results for patient 1061.0
# Questioning patient 1060.0
# Added results for patient 1060.0
# Questioning patient 1059.0
# Added results for patient 1059.0
# Questioning patient 1058.0
# Added results for patient 1058.0
# Questioning patient 1057.0
# Added results for patient 1057.0
# Questioning patient 1056.0
# Added results for patient 1056.0
# checkpoint!
# Questioning patient 1055.0
# Added results for patient 1055.0
# Questioning patient 1054.0
# Added results for patient 1054.0
# Questioning patient 1053.0
# Added results for patient 1053.0
# Questioning patient 1052.0
# Added results for patient 1052.0
# Questioning patient 1051.0
# Added results for patient 1051.0
# Questioning patient 1050.0
# Added results for patient 1050.0
# Questioning patient 1049.0
# Added results for patient 1049.0
# Questioning patient 1048.0
# Added results for patient 1048.0
# Questioning patient 1047.0
# Added results for patient 1047.0
# Questioning patient 1046.0
# Added results for patient 1046.0
# Questioning patient 1045.0
# Added results for patient 1045.0
# Questioning patient 1044.0
# Added results for patient 1044.0
# Questioning patient 1043.0
# Added results for patient 1043.0
# Questioning patient 1042.0
# Added results for patient 1042.0
# Questioning patient 1041.0
# Added results for patient 1041.0
# Questioning patient 917.0
# Added results for patient 917.0
# Questioning patient 916.0
# Added results for patient 916.0
# Questioning patient 915.0
# Added results for patient 915.0
# Questioning patient 914.0
# Added results for patient 914.0
# Questioning patient 913.0
# Added results for patient 913.0
# Questioning patient 912.0
# Added results for patient 912.0
# Questioning patient 911.0
# Added results for patient 911.0
# Questioning patient 910.0
# Added results for patient 910.0
# Questioning patient 909.0
# Added results for patient 909.0
# Questioning patient 908.0
# Added results for patient 908.0
# Questioning patient 907.0
# Added results for patient 907.0
# Questioning patient 906.0
# Added results for patient 906.0
# checkpoint!
# Questioning patient 905.0
# Added results for patient 905.0
# Questioning patient 904.0
# Added results for patient 904.0
# Questioning patient 903.0
# Added results for patient 903.0
# Questioning patient 902.0
# Added results for patient 902.0
# Questioning patient 901.0
# Added results for patient 901.0
# Questioning patient 900.0
# Added results for patient 900.0
# Questioning patient 899.0
# Added results for patient 899.0
# Questioning patient 898.0
# Added results for patient 898.0
# Questioning patient 897.0
# Added results for patient 897.0
# Questioning patient 896.0
# Added results for patient 896.0
# Questioning patient 895.0
# Added results for patient 895.0
# Questioning patient 894.0
# Added results for patient 894.0
# Questioning patient 893.0
# Added results for patient 893.0
# Questioning patient 892.0
# Added results for patient 892.0
# Questioning patient 891.0
# Added results for patient 891.0
# Questioning patient 890.0
# Added results for patient 890.0
# Questioning patient 889.0
# Added results for patient 889.0
# Questioning patient 888.0
# Added results for patient 888.0
# Questioning patient 887.0
# Added results for patient 887.0
# Questioning patient 886.0
# Added results for patient 886.0
# Questioning patient 885.0
# Added results for patient 885.0
# Questioning patient 884.0
# Added results for patient 884.0
# Questioning patient 883.0
# Added results for patient 883.0
# Questioning patient 882.0
# Added results for patient 882.0
# Questioning patient 881.0
# Added results for patient 881.0
# checkpoint!
# Questioning patient 880.0
# Added results for patient 880.0
# Questioning patient 879.0
# Added results for patient 879.0
# Questioning patient 878.0
# Added results for patient 878.0
# Questioning patient 877.0
# Added results for patient 877.0
# Questioning patient 876.0
# Added results for patient 876.0
# Questioning patient 875.0
# Added results for patient 875.0
# Questioning patient 874.0
# Added results for patient 874.0
# Questioning patient 873.0
# Added results for patient 873.0
# Questioning patient 872.0
# Added results for patient 872.0
# Questioning patient 871.0
# Added results for patient 871.0
# Questioning patient 870.0
# Added results for patient 870.0
# Questioning patient 869.0
# Added results for patient 869.0
# Questioning patient 868.0
# Added results for patient 868.0
# Questioning patient 867.0
# Added results for patient 867.0
# Questioning patient 866.0
# Added results for patient 866.0
# Questioning patient 865.0
# Added results for patient 865.0
# Questioning patient 864.0
# Added results for patient 864.0
# Questioning patient 863.0
# Added results for patient 863.0
# Questioning patient 862.0
# Added results for patient 862.0
# Questioning patient 861.0
# Added results for patient 861.0
# Questioning patient 860.0
# Added results for patient 860.0
# Questioning patient 859.0
# Added results for patient 859.0
# Questioning patient 858.0
# Added results for patient 858.0
# Questioning patient 857.0
# Added results for patient 857.0
# Questioning patient 856.0
# Added results for patient 856.0
# checkpoint!
# Questioning patient 855.0
# Added results for patient 855.0
# Questioning patient 854.0
# Added results for patient 854.0
# Questioning patient 853.0
# Added results for patient 853.0
# Questioning patient 852.0
# Added results for patient 852.0
# Questioning patient 851.0
# Added results for patient 851.0
# Questioning patient 850.0
# Added results for patient 850.0
# Questioning patient 849.0
# Added results for patient 849.0
# Questioning patient 848.0
# Added results for patient 848.0
# Questioning patient 847.0
# Added results for patient 847.0
# Questioning patient 846.0
# Added results for patient 846.0
# Questioning patient 845.0
# Added results for patient 845.0
# Questioning patient 844.0
# Added results for patient 844.0
# Questioning patient 843.0
# Added results for patient 843.0
# Questioning patient 842.0
# Added results for patient 842.0
# Questioning patient 841.0
# Added results for patient 841.0
# Questioning patient 840.0
# Added results for patient 840.0
# Questioning patient 839.0
# Added results for patient 839.0
# Questioning patient 838.0
# Added results for patient 838.0
# Questioning patient 837.0
# Added results for patient 837.0
# Questioning patient 836.0
# Added results for patient 836.0
# Questioning patient 835.0
# Added results for patient 835.0
# Questioning patient 834.0
# Added results for patient 834.0
# Questioning patient 833.0
# Added results for patient 833.0
# Questioning patient 832.0
# Added results for patient 832.0
# Questioning patient 831.0
# Added results for patient 831.0
# checkpoint!
# Questioning patient 830.0
# Added results for patient 830.0
# Questioning patient 829.0
# Added results for patient 829.0
# Questioning patient 828.0
# Added results for patient 828.0
# Questioning patient 827.0
# Added results for patient 827.0
# Questioning patient 826.0
# Added results for patient 826.0
# Questioning patient 825.0
# Added results for patient 825.0
# Questioning patient 824.0
# Added results for patient 824.0
# Questioning patient 823.0
# Added results for patient 823.0
# Questioning patient 822.0
# Added results for patient 822.0
# Questioning patient 821.0
# Added results for patient 821.0
# Questioning patient 820.0
# Added results for patient 820.0
# Questioning patient 819.0
# Added results for patient 819.0
# Questioning patient 818.0
# Added results for patient 818.0
# Questioning patient 817.0
# Added results for patient 817.0
# Questioning patient 816.0
# Added results for patient 816.0
# Questioning patient 815.0
# Added results for patient 815.0
# Questioning patient 814.0
# Added results for patient 814.0
# Questioning patient 813.0
# Added results for patient 813.0
# Questioning patient 812.0
# Added results for patient 812.0
# Questioning patient 811.0
# Added results for patient 811.0
# Questioning patient 810.0
# Added results for patient 810.0
# Questioning patient 809.0
# Added results for patient 809.0
# Questioning patient 808.0
# Added results for patient 808.0
# Questioning patient 807.0
# Added results for patient 807.0
# Questioning patient 806.0
# Added results for patient 806.0
# checkpoint!
# Questioning patient 805.0
# Added results for patient 805.0
# Questioning patient 804.0
# Added results for patient 804.0
# Questioning patient 803.0
# Added results for patient 803.0
# Questioning patient 802.0
# Added results for patient 802.0
# Questioning patient 801.0
# Added results for patient 801.0
# Questioning patient 800.0
# Added results for patient 800.0
# Questioning patient 799.0
# Added results for patient 799.0
# Questioning patient 798.0
# Added results for patient 798.0
# Questioning patient 797.0
# Added results for patient 797.0
# Questioning patient 796.0
# Added results for patient 796.0
# Questioning patient 795.0
# Added results for patient 795.0
# Questioning patient 794.0
# Added results for patient 794.0
# Questioning patient 793.0
# Added results for patient 793.0
# Questioning patient 792.0
# Added results for patient 792.0
# Questioning patient 97.0
# Added results for patient 97.0
# Questioning patient 96.0
# Added results for patient 96.0
# Questioning patient 95.0
# Added results for patient 95.0
# Questioning patient 94.0
# Added results for patient 94.0
# Questioning patient 93.0
# Added results for patient 93.0
# Questioning patient 92.0
# Added results for patient 92.0
# Questioning patient 91.0
# Added results for patient 91.0
# Questioning patient 90.0
# Added results for patient 90.0
# Questioning patient 89.0
# Added results for patient 89.0
# Questioning patient 88.0
# Added results for patient 88.0
# Questioning patient 87.0
# Added results for patient 87.0
# Questioning patient 86.0
# Added results for patient 86.0
# Questioning patient 85.0
# Added results for patient 85.0
# Questioning patient 84.0
# Added results for patient 84.0
# Questioning patient 83.0
# Added results for patient 83.0
# Questioning patient 82.0
# Added results for patient 82.0
# Questioning patient 81.0
# Added results for patient 81.0
# checkpoint!
# Questioning patient 80.0
# Added results for patient 80.0
# Questioning patient 79.0
# Added results for patient 79.0
# Questioning patient 78.0
# Added results for patient 78.0
# Questioning patient 77.0
# Added results for patient 77.0
# Questioning patient 76.0
# Added results for patient 76.0
# Questioning patient 75.0
# Added results for patient 75.0
# Questioning patient 74.0
# Added results for patient 74.0
# Questioning patient 73.0
# Added results for patient 73.0
# Questioning patient 72.0
# Added results for patient 72.0
# Questioning patient 71.0
# Added results for patient 71.0
# Questioning patient 70.0
# Added results for patient 70.0
# Questioning patient 69.0
# Added results for patient 69.0
# Questioning patient 68.0
# Added results for patient 68.0
# Questioning patient 67.0
# Added results for patient 67.0
# Questioning patient 66.0
# Added results for patient 66.0
# Questioning patient 65.0
# Added results for patient 65.0
# Questioning patient 64.0
# Added results for patient 64.0
# Questioning patient 63.0
# Added results for patient 63.0
# Questioning patient 62.0
# Added results for patient 62.0
# Questioning patient 61.0
# Added results for patient 61.0
# Questioning patient 60.0
# Added results for patient 60.0
# Questioning patient 59.0
# Added results for patient 59.0
# Questioning patient 58.0
# Added results for patient 58.0
# Questioning patient 57.0
# Added results for patient 57.0
# Questioning patient 56.0
# Added results for patient 56.0
# checkpoint!
# Questioning patient 55.0
# Added results for patient 55.0
# Questioning patient 54.0
# Added results for patient 54.0
# Questioning patient 53.0
# Added results for patient 53.0
# Questioning patient 52.0
# Added results for patient 52.0
# Questioning patient 51.0
# Added results for patient 51.0
# Questioning patient 50.0
# Added results for patient 50.0
# Questioning patient 49.0
# Added results for patient 49.0
# Questioning patient 48.0
# Added results for patient 48.0
# Questioning patient 47.0
# Added results for patient 47.0
# Questioning patient 46.0
# Added results for patient 46.0
# Questioning patient 45.0
# Added results for patient 45.0
# Questioning patient 44.0
# Added results for patient 44.0
# Questioning patient 43.0
# Added results for patient 43.0
# Questioning patient 42.0
# Added results for patient 42.0
# Questioning patient 41.0
# Added results for patient 41.0
# Questioning patient 40.0
# Added results for patient 40.0
# Questioning patient 39.0
# Added results for patient 39.0
# Questioning patient 38.0
# Added results for patient 38.0
# Questioning patient 37.0
# Added results for patient 37.0
# Questioning patient 36.0
# Added results for patient 36.0
# Questioning patient 35.0
# Added results for patient 35.0
# Questioning patient 34.0
# Added results for patient 34.0
# Questioning patient 33.0
# Added results for patient 33.0
# Questioning patient 32.0
# Added results for patient 32.0
# Questioning patient 31.0
# Added results for patient 31.0
# checkpoint!
# Questioning patient 30.0
# Added results for patient 30.0
# Questioning patient 29.0
# Added results for patient 29.0
# Questioning patient 28.0
# Added results for patient 28.0
# Questioning patient 27.0
# Added results for patient 27.0
# Questioning patient 26.0
# Added results for patient 26.0
# Questioning patient 25.0
# Added results for patient 25.0
# Questioning patient 24.0
# Added results for patient 24.0
# Questioning patient 23.0
# Added results for patient 23.0
# Questioning patient 22.0
# Added results for patient 22.0
# Questioning patient 21.0
# Added results for patient 21.0
# Questioning patient 20.0
# Added results for patient 20.0
# Questioning patient 19.0
# Added results for patient 19.0
# Questioning patient 18.0
# Added results for patient 18.0
# Questioning patient 17.0
# Added results for patient 17.0
# Questioning patient 16.0
# Added results for patient 16.0
# Questioning patient 15.0
# Added results for patient 15.0
# Questioning patient 14.0
# Added results for patient 14.0
# Questioning patient 13.0
# Added results for patient 13.0
# Questioning patient 12.0
# Added results for patient 12.0
# Questioning patient 11.0
# Added results for patient 11.0
# Questioning patient 10.0
# Added results for patient 10.0
# Questioning patient 9.0
# Added results for patient 9.0
# Questioning patient 8.0
# Added results for patient 8.0
# Questioning patient 7.0
# Added results for patient 7.0
# Questioning patient 6.0
# Added results for patient 6.0
# checkpoint!
# Questioning patient 5.0
# Added results for patient 5.0
# Questioning patient 4.0
# Added results for patient 4.0
# Questioning patient 3.0
# Added results for patient 3.0
# Questioning patient 2.0
# Added results for patient 2.0
# Questioning patient 1.0
# Added results for patient 1.0

# %%
results.rename(columns = {'patient_id':'id', 'consent':'c4_qa', 'allergy':'c8_qa', 'hiv':'c9_qa', 'hepatitis':'c10_qa', 'opiods':'c12_qa'},
              inplace = True)

# %%
results.to_csv('bert_qa_results.csv', index = False)

# %%
results
# Out:
#           id c4_qa                                              c8_qa c9_qa  \
# 0     1081.0    []                                                 []    []
# 1     1080.0    []                                      [clindamycin]    []
# 2     1079.0    []  [codeine / percocet / erythromycin base / aspi...    []
# 3     1078.0    []  [codeine / percocet / erythromycin base / aspi...    []
# 4     1077.0    []                          [no known drug allergies]    []
# ...      ...   ...                                                ...   ...
# 1076     5.0    []                                                 []    []
# 1077     4.0    []                          [no known drug allergies]    []
# 1078     3.0    []                                                 []    []
# 1079     2.0    []                                                 []    []
# 1080     1.0    []                                                 []    []
#
#      c10_qa c12_qa
# 0        []     []
# 1        []     []
# 2        []     []
# 3        []     []
# 4        []     []
# ...     ...    ...
# 1076     []     []
# 1077     []     []
# 1078     []     []
# 1079     []     []
# 1080     []     []
#
# [1081 rows x 6 columns]

# %%
with open('bert_qa_results.pkl', 'wb') as f:
    pickle.dump(results, f)

# %%
with open('bert_qa_results.pkl', 'rb') as f:
    test = pickle.load(f)

# %%
test['c8_qa'][1]
# Out:
# ['clindamycin']

# %%
test = pd.read_csv('bert_qa_results.csv')

# %%
test['c8_qa'][1]
# Out:
# "['clindamycin']"

# %% [markdown]
# **BMI stuff**

# %%
bmi_results = pd.DataFrame(columns = ['patient_id', 'bmi', 'height', 'weight'])
bmi_questions = questions = {
            'bmi': ['What is the patient’s body mass index?', 'Is the patient obese?'],
            'height': ['What is the patient’s height?'],
            'weight': ['What is the patient’s weight?']}

# %%
for patient, note, i in zip(df['patient_id'], df['notes'], range(len(df))):
    print('Questioning patient', patient)
    # ============ For notes greater than 450 tokens long ================
    # if the note length is greater than the 450 tokens we'll split it and work on each split separately
    note_tokenized = biobert_utility_tokenizer.tokenize(note)
    note_length = len(note_tokenized)
    if note_length > 450:
        # split the data into =<450-sized chunks
        split_n = (note_length // 450) + 1
        split_start = 0
        split_end = 450
        split_text = biobert_utility_tokenizer.convert_tokens_to_string(note_tokenized[split_start:split_end])
        
        # initialize scorer
        scorer = {'patient_id':[patient], 'bmi':[[]], 'height':[[]], 'weight':[[]]}  
        
        for n in range(split_n):
            # if we're in the last split
            if n == (split_n - 1):
                split_text = biobert_utility_tokenizer.convert_tokens_to_string(note_tokenized[note_length - (note_length % 450): ])
                for criteria, index in zip(bmi_questions, range(len(bmi_questions))):
                    if index == 0:
                        continue
                    for question in bmi_questions.get(criteria):
                        mention = biobert_qa(question, split_text)
                        if not pd.isna(mention):
                            scorer[criteria][0].append(mention)
            # otherwise, for each successive split
            elif n != 0:
                split_start += 450
                split_end += 450
                split_text = biobert_utility_tokenizer.convert_tokens_to_string(note_tokenized[split_start:split_end])
                for criteria, index in zip(bmi_questions, range(len(bmi_questions))):
                    if index == 0:
                        continue
                    for question in bmi_questions.get(criteria):
                        mention = biobert_qa(question, split_text)
                        if not pd.isna(mention):
                            scorer[criteria][0].append(mention)
            # for the first split
            elif n == 0:
                for criteria, index in zip(bmi_questions, range(len(bmi_questions))):
                    if index == 0:
                        continue
                    for question in bmi_questions.get(criteria):
                        mention = biobert_qa(question, split_text)
                        if not pd.isna(mention):
                            scorer[criteria][0].append(mention)
        # record results
        scorer_df = pd.DataFrame(scorer)
        bmi_results = bmi_results.append(scorer_df, ignore_index = True)
        print('Added results for patient', patient)
        if i % 25 == 0:
            print('checkpoint!')
            bmi_results.to_csv('bmi_checkpoint_results.csv')
    # =========== For notes less than 450 tokens long ===================
    elif note_length <= 450:
        # set up the scorer dict
        scorer = {'patient_id':[patient], 'bmi':[[]], 'height':[[]], 'weight':[[]]}  
        for criteria, index in zip(bmi_questions, range(len(bmi_questions))):
            if index == 0:
                continue
            for question in bmi_questions.get(criteria):
                mention = biobert_qa(question, note)
                if not pd.isna(mention):
                    scorer[criteria][0].append(mention)

        # record results in the dictionary
        scorer_df = pd.DataFrame(scorer)
        bmi_results = bmi_results.append(scorer_df, ignore_index = True)
        print('Added results for patient', patient)
        if i % 25 == 0:
            print('checkpoint!')
            bmi_results.to_csv('bmi_checkpoint_results.csv')
# Out:
# Questioning patient 1081.0
# Added results for patient 1081.0
# checkpoint!
# Questioning patient 1080.0
# Added results for patient 1080.0
# Questioning patient 1079.0
# Added results for patient 1079.0
# Questioning patient 1078.0
# Added results for patient 1078.0
# Added results for patient 1019.0
# Questioning patient 1018.0
# Added results for patient 1018.0
# Questioning patient 1017.0
# Added results for patient 1017.0
# Questioning patient 1016.0
# Added results for patient 1016.0
# Questioning patient 1015.0
# Added results for patient 1015.0
# Questioning patient 1014.0
# Added results for patient 1014.0
# Questioning patient 1013.0
# Added results for patient 1013.0
# Questioning patient 1012.0
# Added results for patient 1012.0
# Questioning patient 1011.0
# Added results for patient 1011.0
# Questioning patient 1010.0
# Added results for patient 1010.0
# Questioning patient 1009.0
# Added results for patient 1009.0
# Questioning patient 1008.0
# Added results for patient 1008.0
# Questioning patient 1007.0
# Added results for patient 1007.0
# Questioning patient 1006.0
# Added results for patient 1006.0
# checkpoint!
# Questioning patient 1005.0
# Added results for patient 1005.0
# Questioning patient 1004.0
# Added results for patient 1004.0
# Questioning patient 1003.0
# Added results for patient 1003.0
# Questioning patient 1002.0
# Added results for patient 1002.0
# Questioning patient 1001.0
# Added results for patient 1001.0
# Questioning patient 1000.0
# Added results for patient 1000.0
# Questioning patient 999.0
# Added results for patient 999.0
# Questioning patient 998.0
# Added results for patient 998.0
# Questioning patient 997.0
# Added results for patient 997.0
# Questioning patient 996.0
# Added results for patient 996.0
# Questioning patient 995.0
# Added results for patient 995.0
# Questioning patient 994.0
# Added results for patient 994.0
# Questioning patient 993.0
# Added results for patient 993.0
# Questioning patient 992.0
# Added results for patient 992.0
# Questioning patient 991.0
# Added results for patient 991.0
# Questioning patient 990.0
# Added results for patient 990.0
# Questioning patient 989.0
# Added results for patient 989.0
# Questioning patient 988.0
# Added results for patient 988.0
# Questioning patient 987.0
# Added results for patient 987.0
# Questioning patient 986.0
# Added results for patient 986.0
# Questioning patient 985.0
# Added results for patient 985.0
# Questioning patient 984.0
# Added results for patient 984.0
# Questioning patient 983.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-344-cc02110ec682> in <module>
#      35                         continue
#      36                     for question in bmi_questions.get(criteria):
# ---> 37                         mention = biobert_qa(question, split_text)
#      38                         if not pd.isna(mention):
#      39                             scorer[criteria][0].append(mention)
#
# <ipython-input-342-6ac5d078238d> in biobert_qa(question, text)
#       9     text_tokens = biobert_tokenizer.convert_ids_to_tokens(input_ids)
#      10     sep_index = text_tokens.index('[SEP]') + 1
# ---> 11     answer_start_scores, answer_end_scores = biobert_model(**inputs)
#      12
#      13     if torch.max(answer_start_scores) and torch.max(answer_end_scores) < 1:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, start_positions, end_positions)
#    1444             position_ids=position_ids,
#    1445             head_mask=head_mask,
# -> 1446             inputs_embeds=inputs_embeds,
#    1447         )
#    1448
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask)
#     732             head_mask=head_mask,
#     733             encoder_hidden_states=encoder_hidden_states,
# --> 734             encoder_attention_mask=encoder_extended_attention_mask,
#     735         )
#     736         sequence_output = encoder_outputs[0]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask)
#     405
#     406             layer_outputs = layer_module(
# --> 407                 hidden_states, attention_mask, head_mask[i], encoder_hidden_states, encoder_attention_mask
#     408             )
#     409             hidden_states = layer_outputs[0]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask)
#     377             outputs = outputs + cross_attention_outputs[1:]  # add cross attentions if we output attention weights
#     378
# --> 379         intermediate_output = self.intermediate(attention_output)
#     380         layer_output = self.output(intermediate_output, attention_output)
#     381         outputs = (layer_output,) + outputs
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/transformers/modeling_bert.py in forward(self, hidden_states)
#     329
#     330     def forward(self, hidden_states):
# --> 331         hidden_states = self.dense(hidden_states)
#     332         hidden_states = self.intermediate_act_fn(hidden_states)
#     333         return hidden_states
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1610         ret = torch.addmm(bias, input, weight.t())
#    1611     else:
# -> 1612         output = input.matmul(weight.t())
#    1613         if bias is not None:
#    1614             output += bias
#
# KeyboardInterrupt:

# %%
test_case = ['loss of height  5mm nodule',
 'loss of height suspicious for metastatic',
 'vertebral body height of l1 and',
 'loss of height minimal disc space',
 'vertebral body height  tspine plain',
 'maintain normal height multilevel degenerative endplate',
 'loss of height is similar in',
 'lv function height in 66 weight',
 '9884 nsr1409220 height 5 weight 244lbs',
 'left 13082 height 62 weight 4lb',
 'of disc height there is no',
 'examination her height is 5 feet',
 'physical exam height 6 feet 3',
 'mildly atrophic height 68 inches weight',
 'and a height of 5 feet',
 'on presentation height was 5 feet',
 'and her height was 5 2',
 'left 13795 height 64 weight 200',
 '90 pounds height is 61 inches',
 'on presentation height of 5 feet',
 'heart disease height in 69 weight',
 'rate 20 height 52 weight 141',
 'aortic aneurysm height in 60 weight',
 'patient is height was 5 feet',
 '11 osteopenia height loss of 3',
 'cabg procedure height in 58 weight',
 'on admission height is 5 feet',
 'left 15590 height 57 weight 150',
 'examination her height was 5 feet',
 'left 12884 height five feet eight',
 'on admission height 59 weight 104',
 '48 kg height 5 foot 3',
 '12476 left height 5 weight 259',
 '99 kilograms height 5 feet 10',
 'vital signs height 5 ft 7',
 'of vertebral height on',
 'pulse 65 height 5 weight 210',
 'aorta repair height in 75 weight',
 'and body height was preserved hospital',
 'intraop tee height in 61 weight',
 'for avrcabg height in 67 weight',
 'pressure 18285 height 5 feet 10',
 'appropriate carinal height on',
 'mid rca height in 67 weight',
 'presentation her height was 5 feet',
 'on presentation height was 6 feet',
 'of breath height in 67 weight',
 'ventricular function height in 67 weight',
 'sinus rhythm height 59 inch general',
 'physical examination height 6 feet weight']

# %%
for text in test_case:
    print(bert_qa('What is the height?', text))
# Out:
# 5mm
# nan
# l1
# nan
# vertebral body height
# nan
# nan
# nan
# height 5
# 62
# nan
# 5 feet
# 6 feet 3
# 68 inches
# 5 feet
# 5 feet
# 5 2
# 64
# 61 inches
# 5 feet
# heart disease
# 52
# aortic aneurysm
# nan
# nan
# nan
# 5 feet
# height 57
# 5 feet
# five feet eight
# 59
# 5 foot 3
# 5
# 5 feet 10
# 5 ft 7
# nan
# 5
# aorta repair height in 75 weight
# nan
# nan
# nan
# 5 feet 10
# nan
# nan
# 5 feet
# 6 feet
# nan
# nan
# 59 inch general
# 6 feet
